# %%
import pandas as pd

# %% [markdown]
# ### Задание 1
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
# создаем df  с еобходимыми данными: читаем файлы, добавляем названия фильмов, оставляем только название фильма и оценки

df_ratings = pd.read_csv('ratings.csv')
df_movies = pd.read_csv('movies.csv')
df = df_ratings.merge(df_movies)
df = df.filter(items = ['rating', 'title'])
df.head()
# Out:
#    rating             title
# 0     4.0  Toy Story (1995)
# 1     4.0  Toy Story (1995)
# 2     4.5  Toy Story (1995)
# 3     2.5  Toy Story (1995)
# 4     4.5  Toy Story (1995)

# %%
## фильтруем по значению строк рейтинга = 5.0, считаем количество строк по значению столбца с названием фильма

df_rating_5 = df[ df.rating == 5.0 ]
df_rating_5['title'].value_counts().head(1)
# Out:
# Shawshank Redemption, The (1994)    153
# Name: title, dtype: int64

# %% [markdown]
# ### Задание 2
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
data = pd.read_csv('power.csv')
data.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
#создадим df с помощью фильтров по всем условиям, далее суммируем значения quantity

filtered_data = data[( (data['country']=='Latvia') | (data['country']=='Lithuania')  | (data['country']=='Estonia')) 
                     & ((data['category']==4) | (data['category']==12) | (data['category']==21))  
                     & ((data['year'] > 2005) & (data['year'] < 2010))
                     &  (data['quantity'] > 0)]

value = filtered_data['quantity'].sum()
print('Итоговое значение потребления:', value)
# Out:
# Итоговое значение потребления: 164555.0

# %% [markdown]
# ### Задание 3
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):

# %%
df_1 = pd.read_html('https://www.finanz.ru/valyuty/v-realnom-vremeni', encoding='utf-8')[1]
df_1
# Out:
#     Unnamed: 0              Рубль  Предложение  Спрос  Предыдущее закрытие  \
# 0          NaN            GBP/RUB      1042287      -              1043911
# 1          NaN            EUR/RUB       897105      -               898420
# 2          NaN            USD/RUB       738915      -               740545
# 3          NaN            JPY/RUB        06767      -                06776
# 4          NaN            CNY/RUB       114799      -               115044
# 5          NaN            CHF/RUB       819531      -               821261
# 6          NaN               Евро  Предложение  Спрос  Предыдущее закрытие
# 7          NaN            EUR/USD        12140      -                12144
# 8          NaN            EUR/GBP        08606      -                08613
# 9          NaN            EUR/JPY      1325820      -              1326950
# 10         NaN            EUR/CHF        10949      -                10948
# ...
